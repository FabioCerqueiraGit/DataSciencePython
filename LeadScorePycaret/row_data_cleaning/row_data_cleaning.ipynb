# %% [markdown]
# # Lead Scoring Case Study - Row Data Cleaning

# %%
# Import the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the data fromt the excel file

df = pd.read_excel('C:/Users/marce/Desktop/Python/pythoncheatsheets/python_projects/Lead_scoring/archive/Lead_Scoring.xlsx')

df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# 0                            0                   0.0  ...
# 1                          674                   2.5  ...
# 2                         1532                   2.0  ...
# 3                          305                   1.0  ...
# 4                         1428                   1.0  ...
#
#   Get updates on DM Content    Lead Profile    City  \
# 0                        No          Select  Select
# 1                        No          Select  Select
# 2                        No  Potential Lead  Mumbai
# 3                        No          Select  Mumbai
# 4                        No          Select  Mumbai
#
#   Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0                   02.Medium                  02.Medium
# 1                   02.Medium                  02.Medium
# 2                   02.Medium                    01.High
# 3                   02.Medium                    01.High
# 4                   02.Medium                    01.High
#
#   Asymmetrique Activity Score Asymmetrique Profile Score  \
# 0                        15.0                       15.0
# 1                        15.0                       15.0
# 2                        14.0                       20.0
# 3                        13.0                       17.0
# 4                        15.0                       18.0
#
#   I agree to pay the amount through cheque  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              Modified
# 1                                     No          Email Opened
# 2                                    Yes          Email Opened
# 3                                     No              Modified
# 4                                     No              Modified
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (9240, 37)

# %%
# checking the null values

df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# Magazine                                            0
# Newspaper Article                                   0
# X Education Forums                                  0
# Newspaper                                           0
# Digital Advertisement                               0
# Through Recommendations                             0
# Receive More Updates About Our Courses              0
# Tags                                             3353
# Lead Quality                                     4767
# Update me on Supply Chain Content                   0
# Get updates on DM Content                           0
# Lead Profile                                     2709
# City                                             1420
# Asymmetrique Activity Index                      4218
# Asymmetrique Profile Index                       4218
# Asymmetrique Activity Score                      4218
# Asymmetrique Profile Score                       4218
# I agree to pay the amount through cheque            0
# A free copy of Mastering The Interview              0
# Last Notable Activity                               0
# dtype: int64

# %%
# Quantifying Missing data with charts

df.isnull().mean().plot.bar(figsize=(12,6))
plt.ylabel('Percentage of missing values')
plt.xlabel('Variables')
plt.title('Quantifying missing data')
# Out:
# Text(0.5, 1.0, 'Quantifying missing data')

# %%
df.drop(['How did you hear about X Education', 'What is your current occupation', 'What matters most to you in choosing a course', 'Tags', 'Lead Quality'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ... Newspaper  \
# 0                            0                   0.0  ...        No
# 1                          674                   2.5  ...        No
# 2                         1532                   2.0  ...        No
# 3                          305                   1.0  ...        No
# 4                         1428                   1.0  ...        No
#
#   Digital Advertisement Through Recommendations  \
# 0                    No                      No
# 1                    No                      No
# 2                    No                      No
# 3                    No                      No
# 4                    No                      No
#
#   Receive More Updates About Our Courses Update me on Supply Chain Content  \
# 0                                     No                                No
# 1                                     No                                No
# 2                                     No                                No
# 3                                     No                                No
# 4                                     No                                No
#
#   Get updates on DM Content    City I agree to pay the amount through cheque  \
# 0                        No  Select                                       No
# 1                        No  Select                                       No
# 2                        No  Mumbai                                       No
# 3                        No  Mumbai                                       No
# 4                        No  Mumbai                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              Modified
# 1                                     No          Email Opened
# 2                                    Yes          Email Opened
# 3                                     No              Modified
# 4                                     No              Modified
#
# [5 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Prospect ID                                    0
# Lead Number                                    0
# Lead Origin                                    0
# Lead Source                                   36
# Do Not Email                                   0
# Do Not Call                                    0
# Converted                                      0
# TotalVisits                                  137
# Total Time Spent on Website                    0
# Page Views Per Visit                         137
# Last Activity                                103
# Country                                     2461
# Specialization                              1438
# Search                                         0
# Magazine                                       0
# Newspaper Article                              0
# X Education Forums                             0
# Newspaper                                      0
# Digital Advertisement                          0
# Through Recommendations                        0
# Receive More Updates About Our Courses         0
# Update me on Supply Chain Content              0
# Get updates on DM Content                      0
# City                                        1420
# I agree to pay the amount through cheque       0
# A free copy of Mastering The Interview         0
# Last Notable Activity                          0
# dtype: int64

# %%
# drop rows with null values

df.dropna(inplace=True)

# reset the index

df.reset_index(drop=True, inplace=True)

# %%
df.isnull().sum()
# Out:
# Prospect ID                                 0
# Lead Number                                 0
# Lead Origin                                 0
# Lead Source                                 0
# Do Not Email                                0
# Do Not Call                                 0
# Converted                                   0
# TotalVisits                                 0
# Total Time Spent on Website                 0
# Page Views Per Visit                        0
# Last Activity                               0
# Country                                     0
# Specialization                              0
# Search                                      0
# Magazine                                    0
# Newspaper Article                           0
# X Education Forums                          0
# Newspaper                                   0
# Digital Advertisement                       0
# Through Recommendations                     0
# Receive More Updates About Our Courses      0
# Update me on Supply Chain Content           0
# Get updates on DM Content                   0
# City                                        0
# I agree to pay the amount through cheque    0
# A free copy of Mastering The Interview      0
# Last Notable Activity                       0
# dtype: int64

# %%
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 1  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 2  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 3  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
# 4  9fae7df4-169d-489b-afe4-0f3d752542ed       660673  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0  Organic Search           No          No          0          5.0
# 1  Direct Traffic           No          No          1          2.0
# 2  Direct Traffic           No          No          0          1.0
# 3          Google           No          No          1          2.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ... Newspaper  \
# 0                          674                   2.5  ...        No
# 1                         1532                   2.0  ...        No
# 2                          305                   1.0  ...        No
# 3                         1428                   1.0  ...        No
# 4                         1640                   2.0  ...        No
#
#   Digital Advertisement Through Recommendations  \
# 0                    No                      No
# 1                    No                      No
# 2                    No                      No
# 3                    No                      No
# 4                    No                      No
#
#   Receive More Updates About Our Courses Update me on Supply Chain Content  \
# 0                                     No                                No
# 1                                     No                                No
# 2                                     No                                No
# 3                                     No                                No
# 4                                     No                                No
#
#   Get updates on DM Content    City I agree to pay the amount through cheque  \
# 0                        No  Select                                       No
# 1                        No  Mumbai                                       No
# 2                        No  Mumbai                                       No
# 3                        No  Mumbai                                       No
# 4                        No  Mumbai                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No          Email Opened
# 1                                    Yes          Email Opened
# 2                                     No              Modified
# 3                                     No              Modified
# 4                                     No              Modified
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (6173, 27)

# %%
# checking the data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6173 entries, 0 to 6172
# Data columns (total 27 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Prospect ID                               6173 non-null   object
#  1   Lead Number                               6173 non-null   int64
#  2   Lead Origin                               6173 non-null   object
#  3   Lead Source                               6173 non-null   object
#  4   Do Not Email                              6173 non-null   object
#  5   Do Not Call                               6173 non-null   object
#  6   Converted                                 6173 non-null   int64
#  7   TotalVisits                               6173 non-null   float64
#  8   Total Time Spent on Website               6173 non-null   int64
#  9   Page Views Per Visit                      6173 non-null   float64
#  10  Last Activity                             6173 non-null   object
#  11  Country                                   6173 non-null   object
#  12  Specialization                            6173 non-null   object
#  13  Search                                    6173 non-null   object
#  14  Magazine                                  6173 non-null   object
#  15  Newspaper Article                         6173 non-null   object
#  16  X Education Forums                        6173 non-null   object
#  17  Newspaper                                 6173 non-null   object
#  18  Digital Advertisement                     6173 non-null   object
#  19  Through Recommendations                   6173 non-null   object
#  20  Receive More Updates About Our Courses    6173 non-null   object
#  21  Update me on Supply Chain Content         6173 non-null   object
#  22  Get updates on DM Content                 6173 non-null   object
#  23  City                                      6173 non-null   object
#  24  I agree to pay the amount through cheque  6173 non-null   object
#  25  A free copy of Mastering The Interview    6173 non-null   object
#  26  Last Notable Activity                     6173 non-null   object
# dtypes: float64(2), int64(3), object(22)
# memory usage: 1.3+ MB

# %%
# value counts bar chart of column 'Lead Origin'

df['Lead Origin'].value_counts().plot.bar(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
# value counts bar chart of column 'City'

df['City'].value_counts().plot.bar(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
# value counts bar chart of column 'Converted'

df['Converted'].value_counts().plot.bar(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
# save the cleaned data to a new excel file

df.to_excel('C:/Users/marce/Desktop/Python/pythoncheatsheets/python_projects/Lead_scoring/archive/Lead_Scoring_cleaned.xlsx', index=False)
